# %%
from datetime import date

# %%
mi_fecha = date(1972,1, 6)
print(mi_fecha)
# Out:
# 1972-01-06

# %%
print(type(mi_fecha))
# Out:
# <class 'datetime.date'>

# %%
# Dia
print("Dia: ", mi_fecha.day)
# Out:
# Dia:  6

# %%
# Mes
print("Mes: ", mi_fecha.month)
# Out:
# Mes:  1

# %%
# Año
print("Año: ", mi_fecha.year)
# Out:
# Año:  1972

# %%
# Fecha actual
fecha_actual = date.today()
print(fecha_actual)
# Out:
# 2023-05-05

# %%
año_actual = fecha_actual.year

# %%
from datetime import time

# %%
hora = time(12,25,16,11)
print(hora)
# Out:
# 12:25:16.000011

# %%
hora.hour
# Out:
# 12

# %%
minutos = hora.minute
minutos
# Out:
# 25

# %%
hora.second
# Out:
# 16

# %%
#Datetime
import datetime

# %%
hoy_completo = datetime.datetime.now()
hoy_completo
# Out:
# datetime.datetime(2023, 5, 5, 9, 54, 1, 547300)

# %%
hoy_completo.day
# Out:
# 5

# %%
hoy_completo.month
# Out:
# 5

# %%
hoy_completo.year
# Out:
# 2023

# %%
hoy_completo.hour
# Out:
# 9

# %%
hoy_completo.minute
# Out:
# 54

# %%
hoy_completo.second
# Out:
# 1

# %%
tiempo = datetime.datetime(2022,9,27,16,00,30,40)

# %%
print(tiempo.weekday()) # 0 lunes 1 martes 2 miercoles ... 6 domingo
# Out:
# 1

# %%
print(tiempo.isoweekday()) # 1 lunes 2 martes 3 miercoles ... 7 domingo
# Out:
# 2

# %%
fecha = '25 May, 2022 16:25:13'
fecha
# Out:
# '25 May, 2022 16:25:13'

# %%
d1 = datetime.datetime.strptime(fecha, '%d %B, %Y %H:%M:%S')
d1
# Out:
# datetime.datetime(2022, 5, 25, 16, 25, 13)

# %%
print(type(d1))
# Out:
# <class 'datetime.datetime'>

# %%
d1 = datetime.datetime.now()

# %%
print('La fecha de hoy es: ', d1)
# Out:
# La fecha de hoy es:  2023-05-05 10:01:19.428594

# %%
d2 = d1 + datetime.timedelta(days=2)
print("Pasado mañana es ", d2)
# Out:
# Pasado mañana es  2023-05-07 10:01:19.428594

# %%
d3 = d1 + datetime.timedelta(weeks=2)
print("Fecha dos semanas posterior ", d3)
# Out:
# Fecha dos semanas posterior  2023-05-19 10:01:19.428594

# %%
# Fechas pasadas
d2 = d1 - datetime.timedelta(days=4)
print("Dia anterior es ", d2)
# Out:
# Dia anterior es  2023-05-01 10:01:19.428594

# %%
d3 = d1 + datetime.timedelta(weeks=4)
print("Semanas anteriosr ", d3)
# Out:
# Semanas anteriosr  2023-06-02 10:01:19.428594
