# %% [markdown]
# <font color=Green>
#
# # **1.5 Leer un CSV e insertarlo en la BD**
#
# </font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sqlite3
import csv

conexion = sqlite3.connect(r"C:\Users\rafael\Desktop\python\sqlite\ejemplo.db")
cursor = conexion.cursor()

archivo = open(r"C:\Users\rafael\Desktop\python\sqlite\datos_db.txt")

filas = csv.reader(archivo)

cursor.executemany("INSERT INTO estudiantes VALUES (?,?,?,?)", filas)

cursor.execute("SELECT * FROM estudiantes")

print(cursor.fetchall())

conexion.commit()
conexion.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c33e6fdbc307> in <cell line: 7>()
#       5 cursor = conexion.cursor()
#       6
# ----> 7 archivo = open(r"C:\Users\rafael\Desktop\python\sqlite\datos_db.txt")
#       8
#       9 filas = csv.reader(archivo)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\rafael\\Desktop\\python\\sqlite\\datos_db.txt'
