# %%
import pandas as pd

# %%
help(pd.Series.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on some value.
#     - A tuple of row and column indexes. The tuple elements consist of one of the
#       above inputs, e.g. ``(0, 1)``.
#
#     ``.iloc`` will raise ``IndexError`` if a requested indexer is
#     out-of-bounds, except *slice* indexers which allow out-of-bounds
#     indexing (this conforms with python/numpy *slice* semantics).
#
#     See more at :ref:`Selection by Position <indexing.integer>`.
#
#     See Also
#     --------
#     DataFrame.iat : Fast integer location scalar accessor.
#     DataFrame.loc : Purely label-location based indexer for selection by label.
#     Series.iloc : Purely integer-location based indexing for
#                    selection by position.
#
#     Examples
#     --------
#     >>> mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
#     ...           {'a': 100, 'b': 200, 'c': 300, 'd': 400},
#     ...           {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
#     >>> df = pd.DataFrame(mydict)
#     >>> df
#           a     b     c     d
#     0     1     2     3     4
#     1   100   200   300   400
#     2  1000  2000  3000  4000
#
#     **Indexing just the rows**
#
#     With a scalar integer.
#
#     >>> type(df.iloc[0])
#     <class 'pandas.core.series.Series'>
#     >>> df.iloc[0]
#     a    1
#     b    2
#     c    3
#     d    4
#     Name: 0, dtype: int64
#
#     With a list of integers.
#
#     >>> df.iloc[[0]]
#        a  b  c  d
#     0  1  2  3  4
#     >>> type(df.iloc[[0]])
#     <class 'pandas.core.frame.DataFrame'>
#
#     >>> df.iloc[[0, 1]]
#          a    b    c    d
#     0    1    2    3    4
#     1  100  200  300  400
#
#     With a `slice` object.
#
#     >>> df.iloc[:3]
#           a     b     c     d
#     0     1     2     3     4
#     1   100   200   300   400
#     2  1000  2000  3000  4000
#
#     With a boolean mask the same length as the index.
#
#     >>> df.iloc[[True, False, True]]
#           a     b     c     d
#     0     1     2     3     4
#     2  1000  2000  3000  4000
#
#     With a callable, useful in method chains. The `x` passed
#     to the ``lambda`` is the DataFrame being sliced. This selects
#     the rows whose index label even.
#
#     >>> df.iloc[lambda x: x.index % 2 == 0]
#           a     b     c     d
#     0     1     2     3     4
#     2  1000  2000  3000  4000
#
#     **Indexing both axes**
#
#     You can mix the indexer types for the index and columns. Use ``:`` to
#     select the entire axis.
#
#     With scalar integers.
#
#     >>> df.iloc[0, 1]
#     2
#
#     With lists of integers.
#
#     >>> df.iloc[[0, 2], [1, 3]]
#           b     d
#     0     2     4
#     2  2000  4000
#
#     With `slice` objects.
#
#     >>> df.iloc[1:3, 0:3]
#           a     b     c
#     1   100   200   300
#     2  1000  2000  3000
#
#     With a boolean array whose length matches the columns.
#
#     >>> df.iloc[:, [True, False, True, False]]
#           a     c
#     0     1     3
#     1   100   300
#     2  1000  3000
#
#     With a callable function that expects the Series or DataFrame.
#
#     >>> df.iloc[:, lambda df: [0, 2]]
#           a     c
#     0     1     3
#     1   100   300
#     2  1000  3000

# %%
diccionario = [{'a': 2, 'b': 4, 'c': 9}, {'a': 6, 'b': 12, 'c': 19}]

# %%
df = pd.DataFrame(diccionario)
df
# Out:
#    a   b   c
# 0  2   4   9
# 1  6  12  19

# %% [markdown]
# SERIES

# %%
# Creamos una serie
serie = pd.Series([2, 6, -1 , 8, 9, 2.3], index= ['a', 'b', 'c', 'd', 'e', 'f'])
serie
# Out:
# a    2.0
# b    6.0
# c   -1.0
# d    8.0
# e    9.0
# f    2.3
# dtype: float64

# %%
# Borramos una serie
serie2 = serie.drop(['a', 'e'])
serie2
# Out:
# b    6.0
# c   -1.0
# d    8.0
# f    2.3
# dtype: float64

# %%
serie
# Out:
# a    2.0
# b    6.0
# c   -1.0
# d    8.0
# e    9.0
# f    2.3
# dtype: float64

# %%
# Seleccionar
serie[['b', 'a']]
# Out:
# b    6.0
# a    2.0
# dtype: float64

# %%
# Asignación
serie['b'] = 55
serie
# Out:
# a     2.0
# b    55.0
# c    -1.0
# d     8.0
# e     9.0
# f     2.3
# dtype: float64

# %%
# Filtros
# Valores menores a 4
serie[~(serie>4)]
# Out:
# a    2.0
# c   -1.0
# f    2.3
# dtype: float64

# %%
serie[(serie<4)]
# Out:
# a    2.0
# c   -1.0
# f    2.3
# dtype: float64

# %%
# Valor entre intervalos - alt gr + 1 |
serie[(serie < 0) | (serie > 4)]
# Out:
# b    55.0
# c    -1.0
# d     8.0
# e     9.0
# dtype: float64

# %%
# Valores nulos al unir series con diferentes indices
serie3 = pd.Series([7, 5, -4], index=['b', 'c', 'e'])
serie3
# Out:
# b    7
# c    5
# e   -4
# dtype: int64

# %%
serie
# Out:
# a    2.0
# b    6.0
# c   -1.0
# d    8.0
# e    9.0
# f    2.3
# dtype: float64

# %%
serie4 = serie + serie3
serie4
# Out:
# a     NaN
# b    13.0
# c     4.0
# d     NaN
# e     5.0
# f     NaN
# dtype: float64

# %%
serie4 = serie3 + serie
serie4
# Out:
# a     NaN
# b    13.0
# c     4.0
# d     NaN
# e     5.0
# f     NaN
# dtype: float64

# %%
# Operaciones con metodos de relleno
serie.add(serie3,fill_value=0)
# Out:
# a     2.0
# b    13.0
# c     4.0
# d     8.0
# e     5.0
# f     2.3
# dtype: float64

# %%
# Opereaciones de resta
serie4 = serie.sub(serie3, fill_value=0)
serie4
# Out:
# a     2.0
# b    -1.0
# c    -6.0
# d     8.0
# e    13.0
# f     2.3
# dtype: float64

# %%
# Operaciones de multiplicación
serie4 = serie.mul(serie3, fill_value=0)
serie4
# Out:
# a     0.0
# b    42.0
# c    -5.0
# d     0.0
# e   -36.0
# f     0.0
# dtype: float64

# %%
# Operaciones de división
serie4 = serie.div(serie3, fill_value=0)
serie4
# Out:
# a         inf
# b    0.857143
# c   -0.200000
# d         inf
# e   -2.250000
# f         inf
# dtype: float64

# %% [markdown]
# ### DATAFRAME

# %%
datos = {'Alumno':['Maria', 'Lucia', 'Jose', 'Eva'],
         'Nota': [8, 9, 6, 10]}
df= pd.DataFrame(datos, columns=['Alumno', 'Nota'])
df
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %%
# Borrar columna
df.drop('Nota', axis=1)
df
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %%
#Mostrar parte del Dataframe
df.head(2)
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9

# %%
# Mostrar un ejemplo del dataframe
df_ejemplo = df.sample(3)

# %%
# Ordenar el dataframe
df.sort_index()
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %%
# Ordenamos el dataframe 
df_ejemplo.sort_index()
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6

# %%
# Ordenamos por la columna Nota
df.sort_values(by='Nota')
# Out:
#   Alumno  Nota
# 2   Jose     6
# 0  Maria     8
# 1  Lucia     9
# 3    Eva    10

# %%
# Ordenamos por la columna Alumno
df.sort_values(by='Alumno')
# Out:
#   Alumno  Nota
# 3    Eva    10
# 2   Jose     6
# 1  Lucia     9
# 0  Maria     8

# %%
# Asigna rango a las entradas
df.rank()
df
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %%
# Grabar en csv

df.to_csv('misDatos.csv', index=False, columns = ['Alumno', 'Nota'])

# %%
# Leer Dataframe
mis_datos = pd.read_csv('misDatos.csv', header=None,nrows=2)
mis_datos.columns=['Alumno','Nota']
mis_datos
# Out:
#    Alumno  Nota
# 0  Alumno  Nota
# 1   Maria     8

# %%
mis_datos = pd.read_csv('misDatos.csv')
mis_datos.columns=['Alumno','Nota']
mis_datos
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %%
# Grabar en un excel
df.to_excel('misDatos.xlsx',index=False, sheet_name='MiHoja')

# %%
# Leer un excel
mis_datos_excel = pd.read_excel('misDatos.xlsx')
mis_datos_excel
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %% [markdown]
# ### Seleccion

# %%
df
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %%
# Seleccionamos desde el 2 hasta el final
df[2:]
# Out:
#   Alumno  Nota
# 2   Jose     6
# 3    Eva    10

# %%
# Seleccionamos hasta el 1
df [:1]
# Out:
#   Alumno  Nota
# 0  Maria     8

# %%
df[1:3]
# Out:
#   Alumno  Nota
# 1  Lucia     9
# 2   Jose     6

# %%
# Por posicion fila columna
df.iloc[[1],[1]]
# Out:
#    Nota
# 1     9

# %%
# Por etiqueta, fila por indice y columna por valor
df.loc[[1],['Nota']]
# Out:
#    Nota
# 1     9

# %%
# Por etiqueta, fila por indice y columna por valor
df.loc[[2],['Alumno']]
# Out:
#   Alumno
# 2   Jose

# %%
# Filtro
df_mayor9 = df[df['Nota']>8]
df_mayor9
# Out:
#   Alumno  Nota
# 1  Lucia     9
# 3    Eva    10

# %% [markdown]
# ### Obtener información del DataFrame

# %%
# Nos da el número de filas y de columnas
df.shape
# Out:
# (4, 2)

# %%
# Nos informa del indice
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Columnas
df.columns
# Out:
# Index(['Alumno', 'Nota'], dtype='object')

# %%
# Nos da información
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Alumno  4 non-null      object
#  1   Nota    4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
# Nos indica los valores no nulos
df.count()
# Out:
# Alumno    4
# Nota      4
# dtype: int64

# %%
# Suma de valores
df.sum()
# Out:
# Alumno    MariaLuciaJoseEva
# Nota                     33
# dtype: object

# %%
# Nos da la suma acumulada
df.cumsum()
# Out:
#               Alumno  Nota
# 0              Maria     8
# 1         MariaLucia    17
# 2     MariaLuciaJose    23
# 3  MariaLuciaJoseEva    33

# %%
# El minimo
df.min()
# Out:
# Alumno    Eva
# Nota        6
# dtype: object

# %%
# El máximo
df.max()
# Out:
# Alumno    Maria
# Nota         10
# dtype: object

# %%
# REsumen con estadisticas basicas
df.describe()
# Out:
#             Nota
# count   4.000000
# mean    8.250000
# std     1.707825
# min     6.000000
# 25%     7.500000
# 50%     8.500000
# 75%     9.250000
# max    10.000000

# %%
# Obtenemos la media
df.mean()
# Out:
# <ipython-input-89-7d9f3ac2d68b>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Nota    8.25
# dtype: float64

# %%
# Obtenemos la mediana
df.median()
# Out:
# <ipython-input-91-323187082e66>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Nota    8.5
# dtype: float64

# %% [markdown]
# ### Aplicando Funciones

# %%
# Multiplica por 2
multiplica_por_dos = lambda x: x*2

# %%
df
# Out:
#   Alumno  Nota
# 0  Maria     8
# 1  Lucia     9
# 2   Jose     6
# 3    Eva    10

# %%
df['Nota']=df['Nota'].apply(multiplica_por_dos)

# %%
df
# Out:
#   Alumno  Nota
# 0  Maria    16
# 1  Lucia    18
# 2   Jose    12
# 3    Eva    20

# %%
df['Nota'] = df['Nota'] + 25

# %%
cuadrado = lambda x : x**2

# %%
df['Nota']=df['Nota'].apply(cuadrado)

# %%
df
# Out:
#   Alumno  Nota
# 0  Maria  1681
# 1  Lucia  1849
# 2   Jose  1369
# 3    Eva  2025
