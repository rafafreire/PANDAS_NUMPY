# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Escribe una funcion a la que le podamos pasar un diccionario con notas de alumnos y nos devuelva la nota minima, la maxima y la media.

# %%
def dame_estadisticas(notas):
  notas = pd.Series(notas)
  estadisticas = pd.Series([notas.min(), notas.max(), notas.mean()], index=['Minima', 'Maxima', 'Media'])
  return estadisticas

# %%
notas = {'Jose': 6, 'Maria': 4, 'Lucia': 8, 'Manuel': 9}

dame_estadisticas(notas)
# Out:
# Minima    4.00
# Maxima    9.00
# Media     6.75
# dtype: float64

# %% [markdown]
# Crea una serie a partir de una matriz con indices

# %%
# Uso un array de numpy
datos = np.array(['Seat', 'Audi', 'Vw', 'Renault'])
indices = [1, 2, 3, 4]
serie=pd.Series(datos,index=indices)
serie
# Out:
# 1       Seat
# 2       Audi
# 3         Vw
# 4    Renault
# dtype: object

# %% [markdown]
# Crea una serie a partir de un diccionario

# %%
diccionario = {'rojo':3, 'verde':5, 'azul':4, 'amarillo':10}
series=pd.Series(diccionario)
series
# Out:
# rojo         3
# verde        5
# azul         4
# amarillo    10
# dtype: int64

# %% [markdown]
# Crea una serie a partir de una lista

# %%
lista = [1,2, 4, 6, 2, 3, 9]
serie = pd.Series(lista, index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])
serie
# Out:
# a    1
# b    2
# c    4
# d    6
# e    2
# f    3
# g    9
# dtype: int64

# %% [markdown]
# Busca informacion en la web para crear una serie usando la funcion linspace de numpy

# %%
serie = pd.Series(np.linspace(25, 55,8)) # del 2 al 14 con 6 valores
serie
# Out:
# 0    25.000000
# 1    29.285714
# 2    33.571429
# 3    37.857143
# 4    42.142857
# 5    46.428571
# 6    50.714286
# 7    55.000000
# dtype: float64

# %% [markdown]
# Crea una serie con numeros al azar entre 0 y 1

# %%
serie = pd.Series(np.random.rand(15))
serie
# Out:
# 0     0.165774
# 1     0.884045
# 2     0.391271
# 3     0.078211
# 4     0.500198
# 5     0.872545
# 6     0.105676
# 7     0.760431
# 8     0.915367
# 9     0.850304
# 10    0.341585
# 11    0.509102
# 12    0.683047
# 13    0.689874
# 14    0.427060
# dtype: float64

# %% [markdown]
# Muestra los elementos de posiciones 1, 3 y 5 de la serie anterior

# %%
serie[[1,3,5]]
# Out:
# 1    0.884045
# 3    0.078211
# 5    0.872545
# dtype: float64

# %% [markdown]
# Muestra los 2 primeros elementos de la serie anterior

# %%
serie.head(2)
# Out:
# 0    0.165774
# 1    0.884045
# dtype: float64

# %% [markdown]
# Muestra los 2 ultimos elementos de la serie anterior

# %%
serie.tail(2)
# Out:
# 13    0.689874
# 14    0.427060
# dtype: float64

# %%
serie.
